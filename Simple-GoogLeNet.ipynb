# %%
import numpy as np
import os
import matplotlib.pyplot as plt

from keras.models import Model
from keras.layers import Input, Flatten, Add, Dropout, Conv2D, BatchNormalization, Activation, Concatenate
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D, SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import GlobalAveragePooling2D, AveragePooling2D, Reshape, multiply, add, concatenate
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
from keras.initializers import he_normal

# %%
# data preparation
dataset_dir =  r'D:\Project\Deep Learning - Research\programs\MV-couswork\Brain Tumor Data Set\BrainTumorProcessed'
input_shape = (256, 256, 3)
batch_size = 4
num_classes = 2

# %%
# data augumentation
train_datagen = ImageDataGenerator(
rescale = 1./255,
shear_range = 0.2,
zoom_range = 0.2,
horizontal_flip = True)

test_datagen = ImageDataGenerator(
rescale = 1./255
)

# %%
train_generator = train_datagen.flow_from_directory(
    os.path.join(dataset_dir, 'train'),
    target_size = input_shape[:2],
    batch_size = batch_size,
    class_mode = 'binary'
)

validation_generator = train_datagen.flow_from_directory(
    os.path.join(dataset_dir, 'val'),
    target_size = input_shape[:2],
    batch_size = batch_size,
    class_mode = 'binary'
)

test_generator = test_datagen.flow_from_directory(
    os.path.join(dataset_dir, 'test'),
    target_size = input_shape[:2],
    batch_size = batch_size,
    class_mode = 'binary'
)
# Out:
# Found 3103 images belonging to 2 classes.
# Found 665 images belonging to 2 classes.
# Found 666 images belonging to 2 classes.

# %%
# get img from generator
images, labels = next(train_generator)

# show the img
fig, axes = plt.subplots(1, batch_size, figsize=(15, 5))
for i in range(batch_size):
    axes[i].imshow(images[i])
    axes[i].set_title(f'Label: {np.argmax(labels[i])}')  # show label
    axes[i].axis('off')
plt.show()

# %%
def residual_block(inputs, num_filter):
    # Convolution layers
    x = Conv2D(num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(inputs)
    x = Conv2D(num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)

    x = Conv2D(2*num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = Conv2D(2*num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    
    # Skip connection
    if inputs.shape[-1] != num_filter:
        shortcut = Conv2D(2*num_filter, kernel_size=(1,1), padding='same')(inputs)
        shortcut = BatchNormalization()(shortcut)
    else:
        shortcut=inputs
        
    shortcut = MaxPooling2D(pool_size=(4, 4), strides=(4, 4))(shortcut)
    # add skip connection
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
def cbam_block(cbam_feature, ratio=8):
    # Channel Attention Module
    channel_avg = GlobalAveragePooling2D()(cbam_feature)
    channel_max = GlobalAveragePooling2D()(cbam_feature)
    channel_avg = Reshape((1, 1, K.int_shape(cbam_feature)[-1]))(channel_avg)
    channel_max = Reshape((1, 1, K.int_shape(cbam_feature)[-1]))(channel_max)
    channel_avg = Dense(K.int_shape(cbam_feature)[-1] // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(channel_avg)
    channel_max = Dense(K.int_shape(cbam_feature)[-1] // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(channel_max)
    channel_avg = Dense(K.int_shape(cbam_feature)[-1], activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(channel_avg)
    channel_max = Dense(K.int_shape(cbam_feature)[-1], activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(channel_max)
    channel_attention = multiply([cbam_feature, channel_avg + channel_max])

    # Spatial Attention Module
    spatial_avg = K.mean(channel_attention, axis=-1, keepdims=True)
    spatial_max = K.max(channel_attention, axis=-1, keepdims=True)
    spatial_attention = add([spatial_avg, spatial_max])
    spatial_attention = Activation('sigmoid')(spatial_attention)

    return multiply([channel_attention, spatial_attention])

# %%
def model1(inputs):
    
    x = residual_block(inputs, 64) # 2 conv layers
    
    x = cbam_block(x)
    
    x = residual_block(x, 256) # 2 conv layers
    
    x = cbam_block(x)
    
    x = Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    
    return x

# %%
def inception_module(x, filters):
    # 1x1 卷积
    conv1x1_1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu')(x)

    # 1x1 卷积 + 3x3 卷积
    conv1x1_2 = Conv2D(filters[1], (1, 1), padding='same', activation='relu')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu')(conv1x1_2)

    # 1x1 卷积 + 5x5 卷积
    conv1x1_3 = Conv2D(filters[3], (1, 1), padding='same', activation='relu')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu')(conv1x1_3)

    # 3x3 最大池化 + 1x1 卷积
    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    conv1x1_4 = Conv2D(filters[5], (1, 1), padding='same', activation='relu')(maxpool)

    # 拼接所有分支
    inception = concatenate([conv1x1_1, conv3x3, conv5x5, conv1x1_4], axis=-1)
    return inception

# %%
def model2(inputs):
     # 第一个卷积层
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(inputs)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # 第二个卷积层
    x = Conv2D(64, (1, 1), padding='same', activation='relu')(x)
    x = Conv2D(192, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception 模块
    x = inception_module(x, [64, 128, 128, 128, 128, 128])
    x = inception_module(x, [128, 192, 192, 192, 192, 192])
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # 全局平均池化
    x = AveragePooling2D((2, 2))(x)
    
    return x

# %%
 def Models(inputs_shape):    
    inputs = Input(shape=input_shape)
    
#     branch1 = model1(inputs)
    x = model2(inputs)
    
#     x = concatenate([branch1, branch2], axis=-1)
    
    x = cbam_block(x)

#     x = Conv2D(4096, (1,1), activation='relu')(x)

    x = Dropout(0.3)(x)
    x = GlobalAveragePooling2D()(x)
    output = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
model = Models(input_shape)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 192)  110784      ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 192)  0          ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 128)  409728      ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 128)  24704       ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 448)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 192)  86208       ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 192)  86208       ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 448)  0          ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 128)  57472       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 192)  331968      ['conv2d_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 192)  921792      ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 192)  86208       ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 704)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 704)  0          ['concatenate_1[0][0]']
#
#  average_pooling2d (AveragePool  (None, 8, 8, 704)   0           ['max_pooling2d_4[0][0]']
#  ing2D)
#
#  global_average_pooling2d (Glob  (None, 704)         0           ['average_pooling2d[0][0]']
#  alAveragePooling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 704)         0           ['average_pooling2d[0][0]']
#  obalAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 704)    0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  reshape_1 (Reshape)            (None, 1, 1, 704)    0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense (Dense)                  (None, 1, 1, 88)     61952       ['reshape[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 88)     61952       ['reshape_1[0][0]']
#
#  dense_2 (Dense)                (None, 1, 1, 704)    61952       ['dense[0][0]']
#
#  dense_3 (Dense)                (None, 1, 1, 704)    61952       ['dense_1[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 1, 1, 704)   0           ['dense_2[0][0]',
#  da)                                                              'dense_3[0][0]']
#
#  multiply (Multiply)            (None, 8, 8, 704)    0           ['average_pooling2d[0][0]',
#                                                                   'tf.__operators__.add[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  (None, 8, 8, 1)     0           ['multiply[0][0]']
#  a)
#
#  tf.math.reduce_max (TFOpLambda  (None, 8, 8, 1)     0           ['multiply[0][0]']
#  )
#
#  add (Add)                      (None, 8, 8, 1)      0           ['tf.math.reduce_mean[0][0]',
#                                                                   'tf.math.reduce_max[0][0]']
#
#  activation (Activation)        (None, 8, 8, 1)      0           ['add[0][0]']
#
#  multiply_1 (Multiply)          (None, 8, 8, 704)    0           ['multiply[0][0]',
#                                                                   'activation[0][0]']
#
#  dropout (Dropout)              (None, 8, 8, 704)    0           ['multiply_1[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 704)         0           ['dropout[0][0]']
#  obalAveragePooling2D)
#
#  dense_4 (Dense)                (None, 1)            705         ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 2,586,561
# Trainable params: 2,586,561
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import keras.backend as K


def custom_binary_crossentropy(y_true, y_pred):
    epsilon = 1e-15  
    y_pred = K.clip(y_pred, epsilon, 1 - epsilon)  
    loss = - (y_true * K.log(y_pred) + (1 - y_true) * K.log(1 - y_pred))
    return K.mean(loss, axis=-1)


def custom_accuracy(y_true, y_pred):
    y_pred_rounded = K.round(y_pred)
    accuracy = K.mean(K.equal(y_true, y_pred_rounded))
    return accuracy

# %%
from tensorflow.keras.optimizers import Adam

custom_optimizer = Adam(learning_rate=0.01)

model.compile(loss=custom_binary_crossentropy, optimizer="adaGrad", metrics=[custom_accuracy])

# %%
history = model.fit(train_generator, epochs=40, validation_data =(validation_generator), verbose=1)
# Out:
# Epoch 1/40
# 776/776 [==============================] - 53s 64ms/step - loss: 0.6918 - custom_accuracy: 0.5300 - val_loss: 0.6913 - val_custom_accuracy: 0.5344
# Epoch 2/40
# 776/776 [==============================] - 47s 60ms/step - loss: 0.6912 - custom_accuracy: 0.5321 - val_loss: 0.6909 - val_custom_accuracy: 0.5299
# Epoch 3/40
# 776/776 [==============================] - 47s 60ms/step - loss: 0.6908 - custom_accuracy: 0.5320 - val_loss: 0.6911 - val_custom_accuracy: 0.5299
# Epoch 4/40
# 776/776 [==============================] - 47s 60ms/step - loss: 0.6906 - custom_accuracy: 0.5319 - val_loss: 0.6904 - val_custom_accuracy: 0.5344
# Epoch 5/40
# 776/776 [==============================] - 47s 60ms/step - loss: 0.6904 - custom_accuracy: 0.5321 - val_loss: 0.6902 - val_custom_accuracy: 0.5299
# Epoch 6/40
# 776/776 [==============================] - 48s 61ms/step - loss: 0.6901 - custom_accuracy: 0.5321 - val_loss: 0.6898 - val_custom_accuracy: 0.5344
# Epoch 7/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6897 - custom_accuracy: 0.5321 - val_loss: 0.6900 - val_custom_accuracy: 0.5299
# Epoch 8/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6894 - custom_accuracy: 0.5318 - val_loss: 0.6896 - val_custom_accuracy: 0.5344
# Epoch 9/40
# 776/776 [==============================] - 48s 61ms/step - loss: 0.6889 - custom_accuracy: 0.5321 - val_loss: 0.6880 - val_custom_accuracy: 0.5344
# Epoch 10/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6883 - custom_accuracy: 0.5402 - val_loss: 0.6879 - val_custom_accuracy: 0.5299
# Epoch 11/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6874 - custom_accuracy: 0.5433 - val_loss: 0.6869 - val_custom_accuracy: 0.5299
# Epoch 12/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6855 - custom_accuracy: 0.5590 - val_loss: 0.6837 - val_custom_accuracy: 0.6392
# Epoch 13/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6844 - custom_accuracy: 0.5656 - val_loss: 0.6864 - val_custom_accuracy: 0.4850
# Epoch 14/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6825 - custom_accuracy: 0.5713 - val_loss: 0.6796 - val_custom_accuracy: 0.6362
# Epoch 15/40
# 776/776 [==============================] - 48s 61ms/step - loss: 0.6804 - custom_accuracy: 0.5775 - val_loss: 0.6776 - val_custom_accuracy: 0.6347
# Epoch 16/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6794 - custom_accuracy: 0.5935 - val_loss: 0.6748 - val_custom_accuracy: 0.6662
# Epoch 17/40
# 776/776 [==============================] - 48s 61ms/step - loss: 0.6772 - custom_accuracy: 0.6013 - val_loss: 0.6716 - val_custom_accuracy: 0.6497
# Epoch 18/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6738 - custom_accuracy: 0.5995 - val_loss: 0.6716 - val_custom_accuracy: 0.6467
# Epoch 19/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6678 - custom_accuracy: 0.6102 - val_loss: 0.6611 - val_custom_accuracy: 0.6497
# Epoch 20/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6677 - custom_accuracy: 0.6171 - val_loss: 0.6668 - val_custom_accuracy: 0.6452
# Epoch 21/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6634 - custom_accuracy: 0.6066 - val_loss: 0.6565 - val_custom_accuracy: 0.6078
# Epoch 22/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6604 - custom_accuracy: 0.6134 - val_loss: 0.6569 - val_custom_accuracy: 0.6677
# Epoch 23/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6552 - custom_accuracy: 0.6226 - val_loss: 0.6486 - val_custom_accuracy: 0.6587
# Epoch 24/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6514 - custom_accuracy: 0.6410 - val_loss: 0.6499 - val_custom_accuracy: 0.6332
# Epoch 25/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6511 - custom_accuracy: 0.6451 - val_loss: 0.6697 - val_custom_accuracy: 0.5075
# Epoch 26/40
# 776/776 [==============================] - 48s 62ms/step - loss: 0.6497 - custom_accuracy: 0.6511 - val_loss: 0.6509 - val_custom_accuracy: 0.6751
# Epoch 27/40
# 776/776 [==============================] - 47s 61ms/step - loss: 0.6463 - custom_accuracy: 0.6428 - val_loss: 0.6486 - val_custom_accuracy: 0.6692
# Epoch 28/40
# 776/776 [==============================] - 47s 61ms/step - loss: 0.6405 - custom_accuracy: 0.6528 - val_loss: 0.6320 - val_custom_accuracy: 0.6781
# Epoch 29/40
# 776/776 [==============================] - 47s 60ms/step - loss: 0.6356 - custom_accuracy: 0.6608 - val_loss: 0.6421 - val_custom_accuracy: 0.6407
# Epoch 30/40
# 776/776 [==============================] - 47s 60ms/step - loss: 0.6308 - custom_accuracy: 0.6653 - val_loss: 0.6434 - val_custom_accuracy: 0.6692
# Epoch 31/40
# 776/776 [==============================] - 47s 61ms/step - loss: 0.6296 - custom_accuracy: 0.6669 - val_loss: 0.6671 - val_custom_accuracy: 0.6407
# Epoch 32/40
# 776/776 [==============================] - 47s 60ms/step - loss: 0.6282 - custom_accuracy: 0.6745 - val_loss: 0.6244 - val_custom_accuracy: 0.6856
# Epoch 33/40
# 776/776 [==============================] - 47s 60ms/step - loss: 0.6261 - custom_accuracy: 0.6813 - val_loss: 0.6608 - val_custom_accuracy: 0.6377
# Epoch 34/40
# 776/776 [==============================] - 47s 60ms/step - loss: 0.6206 - custom_accuracy: 0.6707 - val_loss: 0.6094 - val_custom_accuracy: 0.7096
# Epoch 35/40
# 776/776 [==============================] - 47s 61ms/step - loss: 0.6218 - custom_accuracy: 0.6793 - val_loss: 0.6230 - val_custom_accuracy: 0.6617
# Epoch 36/40
# 776/776 [==============================] - 47s 61ms/step - loss: 0.6135 - custom_accuracy: 0.6950 - val_loss: 0.6251 - val_custom_accuracy: 0.6692
# Epoch 37/40
# 776/776 [==============================] - 47s 61ms/step - loss: 0.6123 - custom_accuracy: 0.6922 - val_loss: 0.6050 - val_custom_accuracy: 0.7231
# Epoch 38/40
# 776/776 [==============================] - 47s 60ms/step - loss: 0.6082 - custom_accuracy: 0.7036 - val_loss: 0.6524 - val_custom_accuracy: 0.6467
# Epoch 39/40
# 776/776 [==============================] - 50s 65ms/step - loss: 0.6007 - custom_accuracy: 0.7023 - val_loss: 0.6025 - val_custom_accuracy: 0.7171
# Epoch 40/40
# 776/776 [==============================] - 48s 61ms/step - loss: 0.6032 - custom_accuracy: 0.7029 - val_loss: 0.5990 - val_custom_accuracy: 0.7201

# %%
# 画出训练和验证集上的准确率和损失曲线
plt.plot(history.history['custom_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_custom_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training loss', 'Validation loss'], loc='lower right')
plt.show()

# %%
loss, accurancy = model.evaluate(test_generator)
print('Test loss:', loss)
print("Test accurancy", accurancy)
# Out:
# 167/167 [==============================] - 2s 14ms/step - loss: 0.5786 - custom_accuracy: 0.7305
# Test loss: 0.5785677433013916
# Test accurancy 0.7305389046669006

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
x_test, y_test = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size + 1)])
x_test = np.concatenate(x_test)
y_test = np.concatenate(y_test)

# 进行预测并获取预测标签
y_pred = model.predict(x_test)
y_true = y_test

y_pred_tf = (y_pred > 0.5).astype(int).reshape(-1)

# 计算混淆矩阵
conf_matrix = confusion_matrix(y_true, y_pred_tf)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
from sklearn.metrics import precision_score, f1_score

# 将概率转换为二进制标签
y_pred_binary = (y_pred > 0.5).astype(int).reshape(-1)

# 计算 precision (Pc)
precision = precision_score(y_true, y_pred_binary)

# 计算 f1-score
f1 = f1_score(y_true, y_pred_binary)

print(f'Precision (Pc): {precision:.4f}')
print(f'F1-Score: {f1:.4f}')
# Out:
# Precision (Pc): 0.7529
# F1-Score: 0.6887

# %%
#compute precision-recall score
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

#compute precision, recall(sensitivity), and threshold values
precision, recall, thresholds = precision_recall_curve(y_true, y_pred)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(recall, precision)
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Calculate the ROC curve points and the AUC score
fpr, tpr, thresholds = roc_curve(testY, predY)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 from sklearn.metrics import roc_curve, auc
#       3 # Calculate the ROC curve points and the AUC score
# ----> 4 fpr, tpr, thresholds = roc_curve(testY, predY)
#       5 roc_auc = auc(fpr, tpr)
#       7 # Plot the ROC curve
#
# NameError: name 'testY' is not defined

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)

# %%
# model.save("VhRAE.h5")

# %%
import netron
netron.start("VhRAE.h5")
