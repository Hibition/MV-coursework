# %%
import numpy as np
import os
import matplotlib.pyplot as plt

from keras.models import Model
from keras.layers import Input, Flatten, Add, Dropout, Conv2D, BatchNormalization, Activation, Concatenate
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D, SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import GlobalAveragePooling2D, AveragePooling2D, Reshape, multiply, add, concatenate
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
from keras.initializers import he_normal

# %%
# data preparation
dataset_dir =  r'D:\Project\Deep Learning - Research\programs\MV-couswork\Brain Tumor Data Set\BrainTumorProcessed'
input_shape = (256, 256, 3)
batch_size = 4
num_classes = 2

# %%
# data augumentation
train_datagen = ImageDataGenerator(
rescale = 1./255,
shear_range = 0.2,
zoom_range = 0.2,
horizontal_flip = True)

test_datagen = ImageDataGenerator(
rescale = 1./255
)

# %%
train_generator = train_datagen.flow_from_directory(
    os.path.join(dataset_dir, 'train'),
    target_size = input_shape[:2],
    batch_size = batch_size,
    class_mode = 'binary'
)

validation_generator = train_datagen.flow_from_directory(
    os.path.join(dataset_dir, 'val'),
    target_size = input_shape[:2],
    batch_size = batch_size,
    class_mode = 'binary'
)

test_generator = test_datagen.flow_from_directory(
    os.path.join(dataset_dir, 'test'),
    target_size = input_shape[:2],
    batch_size = batch_size,
    class_mode = 'binary'
)
# Out:
# Found 3103 images belonging to 2 classes.
# Found 665 images belonging to 2 classes.
# Found 666 images belonging to 2 classes.

# %%
# get img from generator
images, labels = next(train_generator)

# show the img
fig, axes = plt.subplots(1, batch_size, figsize=(15, 5))
for i in range(batch_size):
    axes[i].imshow(images[i])
    axes[i].set_title(f'Label: {np.argmax(labels[i])}')  # show label
    axes[i].axis('off')
plt.show()

# %%
def residual_block(inputs, num_filter):
    # Convolution layers
    x = Conv2D(num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(inputs)
    x = Conv2D(num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)

    x = Conv2D(2*num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = Conv2D(2*num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    
    # Skip connection
    if inputs.shape[-1] != num_filter:
        shortcut = Conv2D(2*num_filter, kernel_size=(1,1), padding='same')(inputs)
        shortcut = BatchNormalization()(shortcut)
    else:
        shortcut=inputs
        
    shortcut = MaxPooling2D(pool_size=(4, 4), strides=(4, 4))(shortcut)
    # add skip connection
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
def cbam_block(cbam_feature, ratio=8):
    # Channel Attention Module
    channel_avg = GlobalAveragePooling2D()(cbam_feature)
    channel_max = GlobalAveragePooling2D()(cbam_feature)
    channel_avg = Reshape((1, 1, K.int_shape(cbam_feature)[-1]))(channel_avg)
    channel_max = Reshape((1, 1, K.int_shape(cbam_feature)[-1]))(channel_max)
    channel_avg = Dense(K.int_shape(cbam_feature)[-1] // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(channel_avg)
    channel_max = Dense(K.int_shape(cbam_feature)[-1] // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(channel_max)
    channel_avg = Dense(K.int_shape(cbam_feature)[-1], activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(channel_avg)
    channel_max = Dense(K.int_shape(cbam_feature)[-1], activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(channel_max)
    channel_attention = multiply([cbam_feature, channel_avg + channel_max])

    # Spatial Attention Module
    spatial_avg = K.mean(channel_attention, axis=-1, keepdims=True)
    spatial_max = K.max(channel_attention, axis=-1, keepdims=True)
    spatial_attention = add([spatial_avg, spatial_max])
    spatial_attention = Activation('sigmoid')(spatial_attention)

    return multiply([channel_attention, spatial_attention])

# %%
def model1(inputs):
    
    x = residual_block(inputs, 64) # 2 conv layers
    
    x = cbam_block(x)
    
    x = residual_block(x, 256) # 2 conv layers
    
    x = cbam_block(x)
    
    x = Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    
    return x

# %%
def inception_module(x, filters):
    # 1x1 卷积
    conv1x1_1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu')(x)

    # 1x1 卷积 + 3x3 卷积
    conv1x1_2 = Conv2D(filters[1], (1, 1), padding='same', activation='relu')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu')(conv1x1_2)

    # 1x1 卷积 + 5x5 卷积
    conv1x1_3 = Conv2D(filters[3], (1, 1), padding='same', activation='relu')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu')(conv1x1_3)

    # 3x3 最大池化 + 1x1 卷积
    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    conv1x1_4 = Conv2D(filters[5], (1, 1), padding='same', activation='relu')(maxpool)

    # 拼接所有分支
    inception = concatenate([conv1x1_1, conv3x3, conv5x5, conv1x1_4], axis=-1)
    return inception

# %%
def model2(inputs):
     # 第一个卷积层
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(inputs)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # 第二个卷积层
    x = Conv2D(64, (1, 1), padding='same', activation='relu')(x)
    x = Conv2D(192, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception 模块
    x = inception_module(x, [64, 128, 128, 128, 128, 128])
    x = inception_module(x, [128, 192, 192, 192, 192, 192])
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # 全局平均池化
    x = AveragePooling2D((2, 2))(x)
    
    return x

# %%
 def Models(inputs_shape):    
    inputs = Input(shape=input_shape)
    
    branch1 = model1(inputs)
    branch2 = model2(inputs)
    
    x = concatenate([branch1, branch2], axis=-1)
    
    x = cbam_block(x)

#     x = Conv2D(4096, (1,1), activation='relu')(x)

    x = Dropout(0.3)(x)
    x = GlobalAveragePooling2D()(x)
    output = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
model = Models(input_shape)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 12  512         ['input_1[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  batch_normalization (BatchNorm  (None, 256, 256, 12  512        ['conv2d_4[0][0]']
#  alization)                     8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0          ['batch_normalization[0][0]']
#
#  add (Add)                      (None, 64, 64, 128)  0           ['max_pooling2d_1[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  activation (Activation)        (None, 64, 64, 128)  0           ['add[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['activation[0][0]']
#  alAveragePooling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['activation[0][0]']
#  obalAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 128)    0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  reshape_1 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense (Dense)                  (None, 1, 1, 16)     2048        ['reshape[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 16)     2048        ['reshape_1[0][0]']
#
#  dense_2 (Dense)                (None, 1, 1, 128)    2048        ['dense[0][0]']
#
#  dense_3 (Dense)                (None, 1, 1, 128)    2048        ['dense_1[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 1, 1, 128)   0           ['dense_2[0][0]',
#  da)                                                              'dense_3[0][0]']
#
#  multiply (Multiply)            (None, 64, 64, 128)  0           ['activation[0][0]',
#                                                                   'tf.__operators__.add[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  (None, 64, 64, 1)   0           ['multiply[0][0]']
#  a)
#
#  tf.math.reduce_max (TFOpLambda  (None, 64, 64, 1)   0           ['multiply[0][0]']
#  )
#
#  add_1 (Add)                    (None, 64, 64, 1)    0           ['tf.math.reduce_mean[0][0]',
#                                                                   'tf.math.reduce_max[0][0]']
#
#  activation_1 (Activation)      (None, 64, 64, 1)    0           ['add_1[0][0]']
#
#  multiply_1 (Multiply)          (None, 64, 64, 128)  0           ['multiply[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  295168      ['multiply_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 256)  590080      ['conv2d_5[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 512)  66048       ['multiply_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 512)  2359808     ['conv2d_7[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 512)  0          ['conv2d_8[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 512)  0          ['batch_normalization_1[0][0]']
#
#  add_2 (Add)                    (None, 16, 16, 512)  0           ['max_pooling2d_4[0][0]',
#                                                                   'max_pooling2d_5[0][0]']
#
#  activation_2 (Activation)      (None, 16, 16, 512)  0           ['add_2[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 512)         0           ['activation_2[0][0]']
#  obalAveragePooling2D)
#
#  global_average_pooling2d_3 (Gl  (None, 512)         0           ['activation_2[0][0]']
#  obalAveragePooling2D)
#
#  reshape_2 (Reshape)            (None, 1, 1, 512)    0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  reshape_3 (Reshape)            (None, 1, 1, 512)    0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 64  9472        ['input_1[0][0]']
#                                 )
#
#  dense_4 (Dense)                (None, 1, 1, 64)     32768       ['reshape_2[0][0]']
#
#  dense_5 (Dense)                (None, 1, 1, 64)     32768       ['reshape_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 64)  0           ['conv2d_13[0][0]']
#
#  dense_6 (Dense)                (None, 1, 1, 512)    32768       ['dense_4[0][0]']
#
#  dense_7 (Dense)                (None, 1, 1, 512)    32768       ['dense_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   4160        ['max_pooling2d_7[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1, 1, 512)   0           ['dense_6[0][0]',
#  mbda)                                                            'dense_7[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 192)  110784      ['conv2d_14[0][0]']
#
#  multiply_2 (Multiply)          (None, 16, 16, 512)  0           ['activation_2[0][0]',
#                                                                   'tf.__operators__.add_1[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 192)  0          ['conv2d_15[0][0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  (None, 16, 16, 1)   0           ['multiply_2[0][0]']
#  bda)
#
#  tf.math.reduce_max_1 (TFOpLamb  (None, 16, 16, 1)   0           ['multiply_2[0][0]']
#  da)
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 128)  24704       ['max_pooling2d_8[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 128)  24704       ['max_pooling2d_8[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 192)  0          ['max_pooling2d_8[0][0]']
#
#  add_3 (Add)                    (None, 16, 16, 1)    0           ['tf.math.reduce_mean_1[0][0]',
#                                                                   'tf.math.reduce_max_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 64)   12352       ['max_pooling2d_8[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 128)  409728      ['conv2d_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 128)  24704       ['max_pooling2d_9[0][0]']
#
#  activation_3 (Activation)      (None, 16, 16, 1)    0           ['add_3[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 448)  0           ['conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_20[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  multiply_3 (Multiply)          (None, 16, 16, 512)  0           ['multiply_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 192)  86208       ['concatenate[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 192)  86208       ['concatenate[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 32, 32, 448)  0          ['concatenate[0][0]']
#  )
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 512)  2359808     ['multiply_3[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 128)  57472       ['concatenate[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 192)  331968      ['conv2d_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 192)  921792      ['conv2d_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 192)  86208       ['max_pooling2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 512)  2359808     ['conv2d_10[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 704)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_26[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 512)  2359808     ['conv2d_11[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 16, 16, 704)  0          ['concatenate_1[0][0]']
#  )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 512)   0           ['conv2d_12[0][0]']
#
#  average_pooling2d (AveragePool  (None, 8, 8, 704)   0           ['max_pooling2d_11[0][0]']
#  ing2D)
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 1216)   0           ['max_pooling2d_6[0][0]',
#                                                                   'average_pooling2d[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 1216)        0           ['concatenate_2[0][0]']
#  obalAveragePooling2D)
#
#  global_average_pooling2d_5 (Gl  (None, 1216)        0           ['concatenate_2[0][0]']
#  obalAveragePooling2D)
#
#  reshape_4 (Reshape)            (None, 1, 1, 1216)   0           ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  reshape_5 (Reshape)            (None, 1, 1, 1216)   0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_8 (Dense)                (None, 1, 1, 152)    184832      ['reshape_4[0][0]']
#
#  dense_9 (Dense)                (None, 1, 1, 152)    184832      ['reshape_5[0][0]']
#
#  dense_10 (Dense)               (None, 1, 1, 1216)   184832      ['dense_8[0][0]']
#
#  dense_11 (Dense)               (None, 1, 1, 1216)   184832      ['dense_9[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 1, 1, 1216)  0           ['dense_10[0][0]',
#  mbda)                                                            'dense_11[0][0]']
#
#  multiply_4 (Multiply)          (None, 8, 8, 1216)   0           ['concatenate_2[0][0]',
#                                                                   'tf.__operators__.add_2[0][0]']
#
#  tf.math.reduce_mean_2 (TFOpLam  (None, 8, 8, 1)     0           ['multiply_4[0][0]']
#  bda)
#
#  tf.math.reduce_max_2 (TFOpLamb  (None, 8, 8, 1)     0           ['multiply_4[0][0]']
#  da)
#
#  add_4 (Add)                    (None, 8, 8, 1)      0           ['tf.math.reduce_mean_2[0][0]',
#                                                                   'tf.math.reduce_max_2[0][0]']
#
#  activation_4 (Activation)      (None, 8, 8, 1)      0           ['add_4[0][0]']
#
#  multiply_5 (Multiply)          (None, 8, 8, 1216)   0           ['multiply_4[0][0]',
#                                                                   'activation_4[0][0]']
#
#  dropout (Dropout)              (None, 8, 8, 1216)   0           ['multiply_5[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 1216)        0           ['dropout[0][0]']
#  obalAveragePooling2D)
#
#  dense_12 (Dense)               (None, 1)            1217        ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 15,051,777
# Trainable params: 15,050,497
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
import keras.backend as K


# 定义自定义的binary_crossentropy损失函数
def custom_binary_crossentropy(y_true, y_pred):
    epsilon = 1e-15  # 添加一个小的常数以防止log(0)的情况
    y_pred = K.clip(y_pred, epsilon, 1 - epsilon)  # 对预测值进行剪切，确保在 (epsilon, 1-epsilon) 范围内
    loss = - (y_true * K.log(y_pred) + (1 - y_true) * K.log(1 - y_pred))
    return K.mean(loss, axis=-1)


def custom_accuracy(y_true, y_pred):
    # 将预测值四舍五入到最接近的整数（0或1）
    y_pred_rounded = K.round(y_pred)
    # 比较四舍五入后的预测值和真实标签，计算匹配的比例
    accuracy = K.mean(K.equal(y_true, y_pred_rounded))
    return accuracy

# %%
model.compile(loss=custom_binary_crossentropy, optimizer='adaGrad', metrics=[custom_accuracy])

# %%
history = model.fit(train_generator, epochs=40, validation_data =(validation_generator), verbose=1)
# Out:
# Epoch 1/40
# 776/776 [==============================] - 60s 71ms/step - loss: 0.6722 - custom_accuracy: 0.6129 - val_loss: 0.6473 - val_custom_accuracy: 0.5988
# Epoch 2/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.6042 - custom_accuracy: 0.6712 - val_loss: 0.6163 - val_custom_accuracy: 0.6632
# Epoch 3/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.5575 - custom_accuracy: 0.7128 - val_loss: 0.5451 - val_custom_accuracy: 0.7051
# Epoch 4/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.5182 - custom_accuracy: 0.7470 - val_loss: 0.6068 - val_custom_accuracy: 0.6946
# Epoch 5/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.4932 - custom_accuracy: 0.7634 - val_loss: 0.4645 - val_custom_accuracy: 0.7725
# Epoch 6/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.4526 - custom_accuracy: 0.7896 - val_loss: 0.4414 - val_custom_accuracy: 0.7859
# Epoch 7/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.4227 - custom_accuracy: 0.8150 - val_loss: 0.4628 - val_custom_accuracy: 0.7620
# Epoch 8/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.3895 - custom_accuracy: 0.8245 - val_loss: 0.4814 - val_custom_accuracy: 0.7769
# Epoch 9/40
# 776/776 [==============================] - 53s 69ms/step - loss: 0.3656 - custom_accuracy: 0.8382 - val_loss: 0.3560 - val_custom_accuracy: 0.8413
# Epoch 10/40
# 776/776 [==============================] - 54s 70ms/step - loss: 0.3314 - custom_accuracy: 0.8524 - val_loss: 0.3022 - val_custom_accuracy: 0.8832
# Epoch 11/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.3014 - custom_accuracy: 0.8778 - val_loss: 0.2754 - val_custom_accuracy: 0.8832
# Epoch 12/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.2848 - custom_accuracy: 0.8792 - val_loss: 0.2988 - val_custom_accuracy: 0.8802
# Epoch 13/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.2661 - custom_accuracy: 0.8914 - val_loss: 0.2935 - val_custom_accuracy: 0.8608
# Epoch 14/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.2544 - custom_accuracy: 0.9021 - val_loss: 0.2487 - val_custom_accuracy: 0.8982
# Epoch 15/40
# 776/776 [==============================] - 54s 69ms/step - loss: 0.2372 - custom_accuracy: 0.9010 - val_loss: 0.3044 - val_custom_accuracy: 0.8802
# Epoch 16/40
# 776/776 [==============================] - 54s 69ms/step - loss: 0.2194 - custom_accuracy: 0.9098 - val_loss: 0.2053 - val_custom_accuracy: 0.9266
# Epoch 17/40
# 776/776 [==============================] - 53s 69ms/step - loss: 0.2064 - custom_accuracy: 0.9216 - val_loss: 0.2640 - val_custom_accuracy: 0.8952
# Epoch 18/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1955 - custom_accuracy: 0.9269 - val_loss: 0.4014 - val_custom_accuracy: 0.8189
# Epoch 19/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1901 - custom_accuracy: 0.9272 - val_loss: 0.1919 - val_custom_accuracy: 0.9386
# Epoch 20/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1824 - custom_accuracy: 0.9275 - val_loss: 0.2488 - val_custom_accuracy: 0.9222
# Epoch 21/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1757 - custom_accuracy: 0.9317 - val_loss: 0.1791 - val_custom_accuracy: 0.9386
# Epoch 22/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1652 - custom_accuracy: 0.9362 - val_loss: 0.1769 - val_custom_accuracy: 0.9311
# Epoch 23/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1575 - custom_accuracy: 0.9420 - val_loss: 0.2289 - val_custom_accuracy: 0.9102
# Epoch 24/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1544 - custom_accuracy: 0.9387 - val_loss: 0.1795 - val_custom_accuracy: 0.9446
# Epoch 25/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1492 - custom_accuracy: 0.9438 - val_loss: 0.1645 - val_custom_accuracy: 0.9401
# Epoch 26/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1406 - custom_accuracy: 0.9488 - val_loss: 0.1577 - val_custom_accuracy: 0.9506
# Epoch 27/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1353 - custom_accuracy: 0.9477 - val_loss: 0.2155 - val_custom_accuracy: 0.9162
# Epoch 28/40
# 776/776 [==============================] - 53s 69ms/step - loss: 0.1377 - custom_accuracy: 0.9488 - val_loss: 0.1538 - val_custom_accuracy: 0.9461
# Epoch 29/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1261 - custom_accuracy: 0.9507 - val_loss: 0.1189 - val_custom_accuracy: 0.9671
# Epoch 30/40
# 776/776 [==============================] - 53s 69ms/step - loss: 0.1183 - custom_accuracy: 0.9533 - val_loss: 0.1591 - val_custom_accuracy: 0.9446
# Epoch 31/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1185 - custom_accuracy: 0.9562 - val_loss: 0.1164 - val_custom_accuracy: 0.9641
# Epoch 32/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1153 - custom_accuracy: 0.9514 - val_loss: 0.1364 - val_custom_accuracy: 0.9431
# Epoch 33/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1125 - custom_accuracy: 0.9552 - val_loss: 0.1405 - val_custom_accuracy: 0.9461
# Epoch 34/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1017 - custom_accuracy: 0.9642 - val_loss: 0.2203 - val_custom_accuracy: 0.9192
# Epoch 35/40
# 776/776 [==============================] - 53s 69ms/step - loss: 0.0993 - custom_accuracy: 0.9639 - val_loss: 0.1150 - val_custom_accuracy: 0.9701
# Epoch 36/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.0971 - custom_accuracy: 0.9621 - val_loss: 0.1351 - val_custom_accuracy: 0.9611
# Epoch 37/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.1004 - custom_accuracy: 0.9655 - val_loss: 0.1062 - val_custom_accuracy: 0.9671
# Epoch 38/40
# 776/776 [==============================] - 53s 68ms/step - loss: 0.0846 - custom_accuracy: 0.9733 - val_loss: 0.1202 - val_custom_accuracy: 0.9641
# Epoch 39/40
# 776/776 [==============================] - 53s 69ms/step - loss: 0.0829 - custom_accuracy: 0.9681 - val_loss: 0.2122 - val_custom_accuracy: 0.9087
# Epoch 40/40
# 776/776 [==============================] - 54s 69ms/step - loss: 0.0831 - custom_accuracy: 0.9665 - val_loss: 0.2231 - val_custom_accuracy: 0.9177

# %%
# 画出训练和验证集上的准确率和损失曲线
plt.plot(history.history['custom_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_custom_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training loss', 'Validation loss'], loc='lower right')
plt.show()

# %%
loss, accurancy = model.evaluate(test_generator)
print('Test loss:', loss)
print("Test accurancy", accurancy)

# %%
#Compute confusion matrix
from sklearn.metrics import confusion_matrix

#Generate predictions for the test dataset
y_pred = model.predict(test_generator)
y_pred_labels = (y_pred>0.5).astype(int)

#Get the true labels from thee test generator
y_true = test_generator.classes

#compute the confusion matrix
confusion = confusion_matrix(y_true, y_pred_labels)
print("Confusion Matrix:")
print(confusion)

# %%
#compute f1-score
from sklearn.metrics import f1_score

f1 = f1_score(y_true, y_pred_labels)
print('F1-score:', f1)

# %%
#compute precision-recall score
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

#compute precision, recall(sensitivity), and threshold values
precision, recall, thresholds = precision_recall_curve(y_true, y_pred)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(recall, precision)
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(y_true, y_pred)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)

# %%
model.save("VhRAE.h5")

# %%
import netron
netron.start("VhRAE.h5")
# Out:
# Serving 'VhRAE.h5' at http://localhost:8080
# ('localhost', 8080)
